# %% [markdown]
# <a href="https://colab.research.google.com/github/ak786abdullah/pandas-library-practice-/blob/main/pandas%20practice%2C%20notes%26projects%20(basic%20to%20advance).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **PANDAS LIBRARY PRACTICE**

# %% [markdown]
# # Basics of pandas week 1

# %% [markdown]
# Day1: import pandas library

# %%
import pandas as pd # calling pandas as pd
print("wellcome to pandas library ")
# Out:
# wellcome to pandas library

# %% [markdown]
# 📅 Day 2: Series – One Column of Data
# 🧠 What’s a Series?
#
# Think of it as a list with labels — like one column in Excel.

# %%
fruits=['apple','orinage','banana'] # a list of 3 fruits
Series=pd.Series(fruits) # make a series of fruits
print(Series)
# Out:
# 0      apple
# 1    orinage
# 2     banana
# dtype: object

# %% [markdown]
# 📅 Day 3: DataFrame – A Whole Table
# 🧠 What’s a DataFrame?
#
# It’s like a whole spreadsheet table with rows and columns.

# %%
data = {
    "Name": ["Ali", "Sara", "Ahmed"],
    "Age": [12, 13, 11]
}
df=pd.DataFrame(data) # make a dataframe of the data
print(df)
# Out:
#     Name  Age
# 0    Ali   12
# 1   Sara   13
# 2  Ahmed   11

# %% [markdown]
# 📅 Day 4: Reading Data from CSV
# 🧠 What is a CSV?
#
# It’s like a plain text Excel file.

# %%
df=pd.read_csv("student_exam_scores.csv")# load and read "student exam score" csv file
#print(df.head(3)) # show 1st three raws
#print(df.tail(3))# show last three raws
# print(df.info()) # show "data types" and "non null values" of each columns(variables) and "momery usage"
#df.describe() # show descriptive statistics(mean,max ,count ..etc ) of each columns
df.shape # show raws  and columns (raws,column)
# Out:
# (200, 6)

# %% [markdown]
# 📅 Day 6: Selecting Columns or
# 🧠 Accessing  columns:

# %%
df["exam_score"] # select or accces  one columns
df[["exam_score","previous_scores"]] # select or accces multiple columns
# Out:
#      exam_score  previous_scores
# 0          30.2               45
# 1          25.0               55
# 2          35.8               86
# 3          34.0               66
# 4          40.3               71
# ..          ...              ...
# 195        42.7               87
# 196        40.4               92
# 197        28.2               76
# 198        42.0               58
# 199        37.8               68
#
# [200 rows x 2 columns]

# %% [markdown]
# #  Basics of pandas week 2

# %% [markdown]
# 📅 Day 7: Selecting Rows
# 🧠 Two ways:
#
# .iloc[] – by position
#
# .loc[] – by label

# %%
df = pd.DataFrame({
    "Name": ["Ali", "Sara", "Ahmed"],
    "Marks": [88, 92, 75]
}, index=["A", "B", "C"])
print(df)
# Out:
#     Name  Marks
# A    Ali     88
# B   Sara     92
# C  Ahmed     75

# %%
df.iloc[0] # select the  raw at postion 0 (at index 0)
df.loc["A"] # select the raw with label "A" (at index 0 with label "A")
# Out:
# Name     Ali
# Marks     88
# Name: A, dtype: object

# %% [markdown]
# 🐼 Week 2: Data Access & Cleaning – “Start Organizing”
#
#
# 📅 Day 8: selecting & Filtering Rows
# 🧠 Goal:
#
# Pick only the rows you want — like saying:
#
# “Show me students with marks above 80!”

# %%
df[df["Marks"]>80]
df[df['Name']=="ali"] # in Name column select only student which name is  "ali"
# Out:
# Empty DataFrame
# Columns: [Name, Marks]
# Index: []

# %% [markdown]
# **rename  "Marks" columns with "obtained_Marks **

# %%
df=df.rename(columns={"Marks":"Obtained_Marks"})

# %% [markdown]
# 📅 Day 9: Adding New Columns
# 🧠 Goal:
#
# Add useful new info — like saying:
#
# “Let’s add a column showing total marks.”

# %%
df["Total_marks"]=[100,100,100]
print(df)
# Out:
#     Name  Obtained_Marks  Total_marks
# A    Ali              88          100
# B   Sara              92          100
# C  Ahmed              75          100

# %% [markdown]
# **Add a columns that show percentage **

# %%
df["percentage"]= df["Obtained_Marks"]/df["Total_marks"]*100
print(df)
# Out:
#     Name  Obtained_Marks  Total_marks  percentage
# A    Ali              88          100        88.0
# B   Sara              92          100        92.0
# C  Ahmed              75          100        75.0

# %% [markdown]
# 📅 Day 10: Deleting Columns OR raws
# 🧠 Goal:
#
# Remove junk columns or raw  — clean your table!

# %%
df.drop("percentage",axis=1,inplace=True)
#df.drop(2,axis=0,inplace =True) # drop or delete raw at posission 2
# del df["percentage"]# second Method

# %%
print(df)
# Out:
#     Name  Obtained_Marks  Total_marks
# A    Ali              88          100
# B   Sara              92          100
# C  Ahmed              75          100

# %% [markdown]
# 📅 Day 12: Handling Missing Values
# 🧠 Goal:
#
# Deal with empty/missing cells.

# %%
df.isnull().sum() # checking missing value
df.dropna(inplace=True)# delete all raws [which has any missing value ]
df.dropna(how="all",inplace=True) # delete all raws [which has all values are missing]
df.dropna(subset=["Total_marks"]) # delete all raws [if any value missing in "Total_marks"]
df.drop_duplicates(inplace=True) # delete all duplicate raws
df.fillna(0,inplace=True)# fill all missing value with zero
df.fillna(df.mode(),inplace=True) # fill all missing value with mode of df
df.bfill(inplace=True) # backword fill
df.ffill(inplace=True)# forword fill
# I use "inplace=True" means i apply these function on my original dataframe

# %% [markdown]
# 📅 Day 13: Sorting Data
# 🧠 Goal:
#
# Sort rows like ranking — top scorer to bottom!

# %% [markdown]
# | What you want            | Use this                                    |
# | ------------------------ | ------------------------------------------- |
# | Sort smallest to largest | `df.sort_values("column")`                  |
# | Sort largest to smallest | `df.sort_values("column", ascending=False)` |

# %%
df.sort_values(by="Obtained_Marks",ascending=False,inplace=True) # orginize value of "Obtaine_Marks" in decending order (highest to lowest)
df.sort_values(by=["Obtained_Marks","Name"])
# Out:
#     Name  Obtained_Marks  Total_marks
# C  Ahmed              75          100
# A    Ali              88          100
# B   Sara              92          100

# %%
print(df)
# Out:
#     Name  Obtained_Marks  Total_marks
# B   Sara              92          100
# A    Ali              88          100
# C  Ahmed              75          100

# %% [markdown]
# 📅 Day 14: Apply Function to Column
# 🧠 Goal:
#
# Apply custom logic to every row.

# %%
df["Result"]=df["Obtained_Marks"].apply(lambda x: "pass" if x>=50 else "fail")
print(df)
# Out:
#     Name  Obtained_Marks  Total_marks Result
# B   Sara              92          100   pass
# A    Ali              88          100   pass
# C  Ahmed              75          100   pass

# %% [markdown]
# 🎯 Try this:
#
# Create "Category" column:
#
# “A” if marks > 90
#
# “B” if > 80
#
# else “C”

# %%
def Grade(e):
  if e>90:
    return "A"
  elif e>80:
    return "B"
  else:
    return "C"

# %%
df["Grade"]=df["Obtained_Marks"].apply(Grade)

# %% [markdown]
# | axis | What you're moving **along**  |
# | ---- | ----------------------------- |
# | 0    | Moving down the **rows**      |
# | 1    | Moving across the **columns** |

# %% [markdown]
# 🐼 Week 3: Data Analysis & Grouping – “Be the Data Detective”
# 📅 Day 15: Descriptive Statistics – Quick Summary
# 🧠 Goal:
#
# Get quick info like average, count, min, max — in seconds!

# %%
df["Obtained_Marks"].mean() # average of obtained_marks(should be numaric values)
df.count() # number of values in each columns
df['Obtained_Marks'].min() # smallest value in "obtained_marks"(should be numaric values )
df['Obtained_Marks'].max() # largest value in "obtained_marks"(should be numaric values )
df['Obtained_Marks'].median() # middle value in ascending order
df['Obtained_Marks'].std() # standard daviation
df.mode() # most repeated value
df.describe() ## Summary of numeric columns
# Out:
#        Obtained_Marks  Total_marks
# count        3.000000          3.0
# mean        85.000000        100.0
# std          8.888194          0.0
# min         75.000000        100.0
# 25%         81.500000        100.0
# 50%         88.000000        100.0
# 75%         90.000000        100.0
# max         92.000000        100.0

# %% [markdown]
# 📅 Day 16: Count & Value Frequencies
# 🧠 Goal:
#
# Know how many time each value apear in spacific columns
#
# in other words :
# frequency of each value in spacific columns

# %%
df['Result'].value_counts() # how many  passed/failed
df['Obtained_Marks'].value_counts() # how many 92/88/75 in columns (obtained marks)
# Out:
# Obtained_Marks
# 92    1
# 88    1
# 75    1
# Name: count, dtype: int64

# %% [markdown]
# # 📅 Day 17: Grouping with groupby()

# %% [markdown]
#  🧠 Goal: Group data and calculate things like total, average, etc.

# %%
data = {
    'Team': ['Red', 'Blue', 'Red', 'Blue', 'Red', 'Green', 'Blue', 'Green'],
    'Player': ['Ali', 'Sara', 'Hassan', 'Ayesha', 'Omar', 'Bilal', 'Zara', 'Nadia'],
    'Score': [10, 20, 15, 30, 25, 40, 35, 50]
}

df = pd.DataFrame(data)
print(df)
# Out:
#     Team  Player  Score
# 0    Red     Ali     10
# 1   Blue    Sara     20
# 2    Red  Hassan     15
# 3   Blue  Ayesha     30
# 4    Red    Omar     25
# 5  Green   Bilal     40
# 6   Blue    Zara     35
# 7  Green   Nadia     50

# %%
df["Total_score"]=df.groupby("Team")["Score"].transform("sum")
df
# Out:
#     Team  Player  Score  Total_score
# 0    Red     Ali     10           50
# 1   Blue    Sara     20           85
# 2    Red  Hassan     15           50
# 3   Blue  Ayesha     30           85
# 4    Red    Omar     25           50
# 5  Green   Bilal     40           90
# 6   Blue    Zara     35           85
# 7  Green   Nadia     50           90

# %%
df.groupby("Team")["Score"].mean()
# Out:
# Team
# Blue     28.333333
# Green    45.000000
# Red      16.666667
# Name: Score, dtype: float64

# %% [markdown]
#  first it  make three groups (Blue, Green, Red) in "teams " column (combine the same values ) then calculate mean of score of each group

# %%
df.groupby("Team")["Player"].count() # number of players in each team
# Out:
# Team
# Blue     3
# Green    2
# Red      3
# Name: Player, dtype: int64

# %% [markdown]
# # 📅 Day 18: Multiple Aggregations  using .agg()

# %% [markdown]
# 🧠 Goal:
#
# Get multiple summaries of multiple columns  at once using agg().

# %%
df.agg({"Score":["mean","median"]}) # mean and median of score
df.groupby("Team")["Score"].agg(["mean","median"])
#or
df.groupby("Team").agg({"Score":["mean","median"]}) # mean and median of score in each team
df.groupby("Team").agg({"Score":["mean","median"],"Total_score":"mean"}) # mean and median of score and mean of total score of each team
# Out:
#            Score        Total_score
#             mean median        mean
# Team
# Blue   28.333333   30.0        85.0
# Green  45.000000   45.0        90.0
# Red    16.666667   15.0        50.0

# %% [markdown]
# # 📅 Day 19: Sorting After Grouping

# %% [markdown]
# 🧠 Goal:
#
# See top groups — e.g., which team has highest average

# %%
df.groupby('Team')["Score"].mean().sort_values(ascending=False)
# Out:
# Team
# Green    45.000000
# Blue     28.333333
# Red      16.666667
# Name: Score, dtype: float64

# %% [markdown]
# # 📅 Day 20: Pivot Tables (Optional but Powerful)

# %% [markdown]
# 🧠 Goal:
#
# Turn rows into columns to view summaries easily.
#
# Create pivot table for average , median and count  of score and Total_score  per team

# %%
  pd.pivot_table(df,index="Team",aggfunc=["mean","median","count"],values=["Score","Total_score"])
# Out:
#             mean             median             count
#            Score Total_score  Score Total_score Score Total_score
# Team
# Blue   28.333333        85.0   30.0        85.0     3           3
# Green  45.000000        90.0   45.0        90.0     2           2
# Red    16.666667        50.0   15.0        50.0     3           3

# %% [markdown]
# # 🧠 Day 22: Combining DataFrames with concat()

# %% [markdown]
# 🐼 Week 4: Advanced Data Skills & Custom Logic

# %% [markdown]
# 🎯 Real-life Analogy:
#
# Imagine two class registers:
#
# One for Class A
#
# One for Class B
#
# You want to combine both into one full student list.
# This is exactly what concat() and append() help us do!
#
# 🔧 Method : pd.concat() – Stack or Glue DataFrames
# ✨ Combine Vertically (Add Rows):

# %%
import pandas as pd

# Class A
df1 = pd.DataFrame({
    "Name": ["Ali", "Sara"],
    "Class": ["6A", "6A"]
})

# Class B
df2 = pd.DataFrame({
    "Name": ["Ahmed", "Fatima"],
    "Class": ["6B", "6B"]
})

# Combine both
combined1=pd.concat([df1,df2],ignore_index=True) # by default it combine both dataframes vertically(add raws)
print(combined1)
# Out:
#      Name Class
# 0     Ali    6A
# 1    Sara    6A
# 2   Ahmed    6B
# 3  Fatima    6B

# %% [markdown]
# Combine Horizontally (Add Columns)
#
# first combine math and science marks in one dataframe

# %%
df1 = pd.DataFrame({"Math": [80, 90,77,93]})
df2 = pd.DataFrame({"Science": [85, 95,75,80]})
combined2=pd.concat([df1,df2],axis=1) # it combine df1, df2 horizantlly (add columns)
print(combined2)
# Out:
#    Math  Science
# 0    80       85
# 1    90       95
# 2    77       75
# 3    93       80

# %% [markdown]
# now combine "name",'class'(combined1) and "math" ,"science" marks(combined2)

# %%
full_class=pd.concat([combined1,combined2],axis=1 ) # (horizantally) fullclass in one dataframe
print(full_class)
# Out:
#      Name Class  Math  Science
# 0     Ali    6A    80       85
# 1    Sara    6A    90       95
# 2   Ahmed    6B    77       75
# 3  Fatima    6B    93       80

# %% [markdown]
# now add a new column named "Section" with values "morning" and "evening"

# %%
full_class["Section"]=['Morning','Morning','Evening','Evening']
print(full_class)
# Out:
#      Name Class  Math  Science  Section
# 0     Ali    6A    80       85  Morning
# 1    Sara    6A    90       95  Morning
# 2   Ahmed    6B    77       75  Evening
# 3  Fatima    6B    93       80  Evening

# %% [markdown]
# # 🔗  Concatenation with Hierarchical Indexing (MultiIndex) using keys=

# %% [markdown]
# When you combine multiple DataFrames using pd.concat(), you can use the keys= parameter to:
#
# 🧩 Group the original DataFrames under separate labels (like folders inside a bigger folder).
#
# This creates a MultiIndex, which helps keep track of where each row originally came from.

# %% [markdown]
# 🧺 Analogy:
#
# Imagine you have two notebooks:
#
# 📘 Boys with 2 students
#
# 📕 Girls with 2 students
#
# You stack them together in single notebook, but want to remember which student came from which notebook.
# So you label   with "Boys" or "Girls" → That’s exactly what keys= does.

# %%
import pandas as pd

# 🧑 Boys DataFrame
boys = pd.DataFrame({
    "Name": ["Ali", "Usman", "Bilal"],
    "Math": [90, 85, 88],
    "English": [80, 78, 82]
})

# 👧 Girls DataFrame
girls = pd.DataFrame({
    "Name": ["Sara", "Hina", "Zara"],
    "Math": [95, 88, 91],
    "English": [89, 92, 90]
})

# %%
# Combine using keys
combined_notebook=pd.concat([boys,girls],axis=0,keys=["Boys","Girls"])
print(combined_notebook)
# Out:
#           Name  Math  English
# Boys  0    Ali    90       80
#       1  Usman    85       78
#       2  Bilal    88       82
# Girls 0   Sara    95       89
#       1   Hina    88       92
#       2   Zara    91       90

# %% [markdown]
# | Setting            | `keys` label appears on |
# | ------------------ | ----------------------- |
# | `axis=0` (default) | Rows                    |
# | `axis=1`           | Columns                 |

# %% [markdown]
# ✅ Task 1: Show all the girls' data

# %%
combined_notebook.loc["Girls"] # accessing girl section
# Out:
#    Name  Math  English
# 0  Sara    95       89
# 1  Hina    88       92
# 2  Zara    91       90

# %% [markdown]
# Task 2: Show all boys' Math scores

# %%
combined_notebook.loc["Boys","Math"]
# Out:
# 0    90
# 1    85
# 2    88
# Name: Math, dtype: int64

# %% [markdown]
# Task 3: Access Bilal’s full record

# %%
combined_notebook.loc[("Boys",2)] # method 1
combined_notebook[combined_notebook["Name"]=="Bilal"] # method 2
# Out:
#          Name  Math  English
# Boys 2  Bilal    88       82

# %% [markdown]
# Task 4: Access Zara’s English score

# %%
combined_notebook.loc[("Girls",2),"English"]
# Out:
# np.int64(90)

# %% [markdown]
# Task 5 (Bonus): Find the average marks in each subject for boys and girls separately

# %%
combined_notebook.groupby(level=0).mean(numeric_only=True)
# Out:
#             Math    English
# Boys   87.666667  80.000000
# Girls  91.333333  90.333333

# %% [markdown]
# #  🧠 Day 23: Merging DataFrames

# %% [markdown]
# 📌 Why Learn merge()?
#
#
# You use it when you want to combine two DataFrames based on a common column, like:
#
# Student IDs
#
# Names
#
# Roll numbers
#
# merge() means connecting two DataFrames using a common piece (column)

# %% [markdown]
# 🗂️ DataFrame 1: Students Info

# %%
import pandas as pd

df1 = pd.DataFrame({
    "Name": ["Ali", "Sara", "Ahmed"],
    "Roll_No": [101, 102, 103],
    "Class": ["6A", "6A", "6B"]
})
print(df1)
# Out:
#     Name  Roll_No Class
# 0    Ali      101    6A
# 1   Sara      102    6A
# 2  Ahmed      103    6B

# %% [markdown]
# 🗂️ DataFrame 2: Exam Marks

# %%
df2 = pd.DataFrame({
    "Roll_No": [101, 102, 103],
    "Class": ["6A", "6A", "6B"],
    "Math": [88, 92, 75],
    "English": [90, 95, 80]
})
print(df2)
# Out:
#    Roll_No Class  Math  English
# 0      101    6A    88       90
# 1      102    6A    92       95
# 2      103    6B    75       80

# %% [markdown]
# as we can see "Roll_No" and 'Class' both are common columns in both dataframes so for connecting them  we use merge() on Roll_No and Class

# %%
merged=pd.merge(df1,df2,on=["Roll_No","Class"])
print(merged)
# Out:
#     Name  Roll_No Class  Math  English
# 0    Ali      101    6A    88       90
# 1   Sara      102    6A    92       95
# 2  Ahmed      103    6B    75       80

# %% [markdown]
# When we use pd.merge(df1, df2) without specifying on=, it will:
#
# 🔎 Automatically merge on all columns that have the same name in both DataFrames.
#
# 🚨 Important Note:
#
# This only works safely when you're sure the same-named columns in both DataFrames should be used to match.
# Otherwise, you should manually specify on=,

# %% [markdown]
# 🧠 What is how=?
#
# it is perameter of merge()
#
# defination:
#
# ,Which rows to keep when combining two DataFrames.

# %% [markdown]
# 📄 df1 — Students

# %%
df1 = pd.DataFrame({
    "Roll_No": [101, 102, 103],
    "Name": ["Ali", "Sara", "Ahmed"]
})
df1
# Out:
#    Roll_No   Name
# 0      101    Ali
# 1      102   Sara
# 2      103  Ahmed

# %% [markdown]
# 📄 df2 — Marks

# %%
df2 = pd.DataFrame({
    "Roll_No": [101, 102, 104],
    "Math": [88, 92, 79]
})
df2
# Out:
#    Roll_No  Math
# 0      101    88
# 1      102    92
# 2      104    79

# %% [markdown]
# how="inner"

# %%
pd.merge(df1,df2,on="Roll_No", how="inner") #inner only keeps rows that match in both → 101 & 102
# Out:
#    Roll_No  Name  Math
# 0      101   Ali    88
# 1      102  Sara    92

# %% [markdown]
#  how= "left"

# %%
pd.merge(df1,df2,on= "Roll_No",how="left") #left keeps all rows from df1, fills unmatched with NaN
# Out:
#    Roll_No   Name  Math
# 0      101    Ali  88.0
# 1      102   Sara  92.0
# 2      103  Ahmed   NaN

# %% [markdown]
# how= "outer"

# %%
pd.merge(df1,df2,on="Roll_No",how="outer") # outer keep all raws,fil unmatchedl with NaN)
# Out:
#    Roll_No   Name  Math
# 0      101    Ali  88.0
# 1      102   Sara  92.0
# 2      103  Ahmed   NaN
# 3      104    NaN  79.0

# %% [markdown]
# how="right"

# %%
pd.merge(df1,df2,on="Roll_No",how="right") #right keeps all rows from df2, fills unmatched with NaN
# Out:
#    Roll_No  Name  Math
# 0      101   Ali    88
# 1      102  Sara    92
# 2      104   NaN    79

# %% [markdown]
# 🧩 Mini Project: School Result Dashboard (Using merge)
# 🎓 Scenario:
#
# You are a data analyst for a school. You have:
#
# A student list
#
# A marksheet for different subjects
#
# A classroom assignment list
#
# Your job is to:
#
# Combine the data using merge()
#
# Calculate total marks
#
# Identify top scorers in each class

# %% [markdown]
# **DataFrames**

# %%
import pandas as pd

# Students list
students = pd.DataFrame({
    "Roll_No": [101, 102, 103, 104],
    "Name": ["Ali", "Sara", "Ahmed", "Hina"]
})

# Marks sheet
marks = pd.DataFrame({
    "Roll_No": [101, 102, 103],
    "Math": [88, 92, 75],
    "English": [90, 95, 80]
})

# Class assignment
classes = pd.DataFrame({
    "Roll_No": [101, 102, 103, 104],
    "Class": ["6A", "6A", "6B", "6C"]
})

# %% [markdown]
# first cimbine students and marks on roll_No

# %%
students_marks=pd.merge(students,marks,on="Roll_No",how="left")
students_marks
# Out:
#    Roll_No   Name  Math  English
# 0      101    Ali  88.0     90.0
# 1      102   Sara  92.0     95.0
# 2      103  Ahmed  75.0     80.0
# 3      104   Hina   NaN      NaN

# %% [markdown]
# now combine  students_marks and classes on roll_no
#
# Note:
#
# i combined on "Roll_No" becouse it is common in all dataframes )

# %%
students_marks_classes=pd.merge(students_marks,classes,on="Roll_No")
students_marks_classes
# Out:
#    Roll_No   Name  Math  English Class
# 0      101    Ali  88.0     90.0    6A
# 1      102   Sara  92.0     95.0    6A
# 2      103  Ahmed  75.0     80.0    6B
# 3      104   Hina   NaN      NaN    6C

# %% [markdown]
# now fill NaN values with 0

# %%
students_marks_classes.fillna(0,inplace=True)
students_marks_classes
# Out:
#    Roll_No   Name  Math  English Class
# 0      101    Ali  88.0     90.0    6A
# 1      102   Sara  92.0     95.0    6A
# 2      103  Ahmed  75.0     80.0    6B
# 3      104   Hina   0.0      0.0    6C

# %% [markdown]
# ** Add  Total_Marks**

# %%
students_marks_classes["Total_Marks"]=students_marks_classes["Math"]+students_marks_classes["English"]
students_marks_classes
# Out:
#    Roll_No   Name  Math  English Class  Total_Marks
# 0      101    Ali  88.0     90.0    6A        178.0
# 1      102   Sara  92.0     95.0    6A        187.0
# 2      103  Ahmed  75.0     80.0    6B        155.0
# 3      104   Hina   0.0      0.0    6C          0.0

# %% [markdown]
# Identify top scorers in each class

# %%
# Group by class and find the top scorer in each group using nlargest
top_scorers_per_class = students_marks_classes.groupby("Class", group_keys=False).apply(lambda x: x.nlargest(1, "Total_Marks"))

# Display the top scorers
print(top_scorers_per_class)
# Out:
#    Roll_No   Name  Math  English Class  Total_Marks
# 1      102   Sara  92.0     95.0    6A        187.0
# 2      103  Ahmed  75.0     80.0    6B        155.0
# 3      104   Hina   0.0      0.0    6C          0.0
# /tmp/ipython-input-2184357466.py:2: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   top_scorers_per_class = students_marks_classes.groupby("Class", group_keys=False).apply(lambda x: x.nlargest(1, "Total_Marks"))

# %% [markdown]
# ** now Export to CSV**

# %%
students_marks_classes.to_csv("students_result.csv",index=False)
pd.read_csv("students_result.csv")
# Out:
#    Roll_No   Name  Math  English Class  Total_Marks
# 0      101    Ali  88.0     90.0    6A        178.0
# 1      102   Sara  92.0     95.0    6A        187.0
# 2      103  Ahmed  75.0     80.0    6B        155.0
# 3      104   Hina   0.0      0.0    6C          0.0

# %% [markdown]
# #  🔗 Day 24: join() Method in Pandas

# %% [markdown]
# 📌 Why learn .join() when we already have merge()?
#
# Because join() is:
#
# 🪄 A simpler and faster way to combine DataFrames when you're joining on the index (not columns).

# %%
df1 = pd.DataFrame({
    "Name": ["Ali", "Sara", "ahmad"]
}, index=[101, 102,103])

df2 = pd.DataFrame({
    "Math": [88, 92]
}, index=[101, 102])

joined=df1.join(df2) #by default, keeps left dataframe index
print(joined)
# Out:
#       Name  Math
# 101    Ali  88.0
# 102   Sara  92.0
# 103  ahmad   NaN

# %% [markdown]
# **Note:**
# how="inner","outer","right","left" are also perameters of .join()

# %% [markdown]
# ⚠️ But be careful:
#
# If you reverse the order like df_marks.join(df_names), you'll get a different result — now df_marks becomes the left one.

# %% [markdown]
# # Mini Project – Class Results Management Using Pandas

# %% [markdown]
# 🎓 Scenario
#
# You’re a data manager for a school. You have:
#
# Two notebooks (DataFrames): Class 6A and Class 6B
#
# Each has students' names and marks in Math and English
#
# You need to:
#
# Combine both classes
#
# Add total marks
#
# Assign grades
#
# Sort toppers
#
# Export result to CSV

# %%
import pandas as pd

# Class 6A
class6A = pd.DataFrame({
    "Name": ["Ali", "Usman", "Bilal"],
    "Math": [88, 75, 90],
    "English": [80, 70, 85]
})

# Class 6B
class6B = pd.DataFrame({
    "Name": ["Sara", "Hina", "Zara"],
    "Math": [95, 91, 88],
    "English": [89, 92, 90]
})

# %% [markdown]
# Combine both classes

# %%
full_class=pd.concat([class6A,class6B],axis=0,keys=["Boys","Girls"])
print(full_class)
# Out:
#           Name  Math  English
# Boys  0    Ali    88       80
#       1  Usman    75       70
#       2  Bilal    90       85
# Girls 0   Sara    95       89
#       1   Hina    91       92
#       2   Zara    88       90

# %% [markdown]
# Add total marks

# %%
full_class["Total_Marks"]=full_class["Math"]+full_class["English"]
print(full_class)
# Out:
#           Name  Math  English  Total_Marks
# Boys  0    Ali    88       80          168
#       1  Usman    75       70          145
#       2  Bilal    90       85          175
# Girls 0   Sara    95       89          184
#       1   Hina    91       92          183
#       2   Zara    88       90          178

# %% [markdown]
# Assign grades

# %%
def assign_grade(e):
  if e>180:
    return "A"
  elif e>170:
    return "B"
  elif e>160:
    return "C"
  else:
    return "F"
# grade assigning to total_marks
full_class["Grade"]=full_class["Total_Marks"].apply(assign_grade)
print(full_class)
# Out:
#           Name  Math  English  Total_Marks Grade
# Boys  0    Ali    88       80          168     C
#       1  Usman    75       70          145     F
#       2  Bilal    90       85          175     B
# Girls 0   Sara    95       89          184     A
#       1   Hina    91       92          183     A
#       2   Zara    88       90          178     B

# %% [markdown]
# Sort toppers

# %%
full_class.sort_values(by="Total_Marks",ascending=False,inplace=True)
print(full_class)
# Out:
#           Name  Math  English  Total_Marks Grade
# Girls 0   Sara    95       89          184     A
#       1   Hina    91       92          183     A
#       2   Zara    88       90          178     B
# Boys  2  Bilal    90       85          175     B
#       0    Ali    88       80          168     C
#       1  Usman    75       70          145     F

# %% [markdown]
# Export result to CSV

# %%
full_class.to_csv("final_result.csv",index=False)
pd.read_csv("final_result.csv")
# Out:
#     Name  Math  English  Total_Marks Grade
# 0   Sara    95       89          184     A
# 1   Hina    91       92          183     A
# 2   Zara    88       90          178     B
# 3  Bilal    90       85          175     B
# 4    Ali    88       80          168     C
# 5  Usman    75       70          145     F

# %%
print(" Boys:")
print(full_class.loc["Boys"])

print("Topper:")
print(full_class[full_class["Grade"] == "A"])

print("Students with Grade B:")
print(full_class[full_class["Grade"] == "B"])
# Out:
#  Boys:
#     Name  Math  English  Total_Marks Grade
# 2  Bilal    90       85          175     B
# 0    Ali    88       80          168     C
# 1  Usman    75       70          145     F
# Topper:
#          Name  Math  English  Total_Marks Grade
# Girls 0  Sara    95       89          184     A
#       1  Hina    91       92          183     A
# Students with Grade B:
#           Name  Math  English  Total_Marks Grade
# Girls 2   Zara    88       90          178     B
# Boys  2  Bilal    90       85          175     B

# %% [markdown]
# **DATA CLEANING**

# %%
import pandas as pd
import numpy as np

# Sample student data from multiple classes
data = {
    "Student_ID": [101, 102, 103, 104, 105, 106, 107, 108, 109, 110],
    "Name": ["Ali", "Sara", "Ahmed", "Fatima", "Usman", "Hina", "Bilal", "Zara", "Kashif", "Sana"],
    "Class": ["6th", "6th", "6th", "7th", "7th", "7th", "8th", "8th", "8th", "8th"],
    "Maths": [85, 90, np.nan, 78, 82, 88, 92, np.nan, 74, 80],
    "Science": [88, np.nan, 75, 80, 85, 90, 95, 89, np.nan, 84],
    "English": [80, 85, 78, 82, np.nan, 87, 91, 85, 79, np.nan]
}

df = pd.DataFrame(data)

print("Sample DataFrame:")
print(df)
# Out:
# Sample DataFrame:
#    Student_ID    Name Class  Maths  Science  English
# 0         101     Ali   6th   85.0     88.0     80.0
# 1         102    Sara   6th   90.0      NaN     85.0
# 2         103   Ahmed   6th    NaN     75.0     78.0
# 3         104  Fatima   7th   78.0     80.0     82.0
# 4         105   Usman   7th   82.0     85.0      NaN
# 5         106    Hina   7th   88.0     90.0     87.0
# 6         107   Bilal   8th   92.0     95.0     91.0
# 7         108    Zara   8th    NaN     89.0     85.0
# 8         109  Kashif   8th   74.0      NaN     79.0
# 9         110    Sana   8th   80.0     84.0      NaN

# %% [markdown]
# Clean missing values

# %%
df.isnull().sum()
df.dropna(how="all",inplace=True)
df.fillna(33,inplace=True)# only pass the student who's marks are missed
print(df)
# Out:
#    Student_ID    Name Class  Maths  Science  English
# 0         101     Ali   6th   85.0     88.0     80.0
# 1         102    Sara   6th   90.0     33.0     85.0
# 2         103   Ahmed   6th   33.0     75.0     78.0
# 3         104  Fatima   7th   78.0     80.0     82.0
# 4         105   Usman   7th   82.0     85.0     33.0
# 5         106    Hina   7th   88.0     90.0     87.0
# 6         107   Bilal   8th   92.0     95.0     91.0
# 7         108    Zara   8th   33.0     89.0     85.0
# 8         109  Kashif   8th   74.0     33.0     79.0
# 9         110    Sana   8th   80.0     84.0     33.0

# %% [markdown]
# # final project

# %% [markdown]
# **load_data**

# %%
import pandas as pd
data=pd.read_csv("messy_school_data.csv")

print(f"data shape:{data.shape}")
print(data.head(6))
# Out:
# data shape:(6, 5)
#    Roll_No   Name  Math  English Class
# 0    101.0   Ali   88.0     80.0    6A
# 1    102.0   sara   NaN     70.0    6A
# 2    103.0  AHMED  75.0      NaN    6B
# 3    104.0   hina  90.0     85.0    6B
# 4    104.0   hina  90.0     85.0    6B
# 5      NaN  Usman  80.0     88.0    6C

# %% [markdown]
# Check how many values are missing in each column.

# %%
print(data.isnull().sum())
# Out:
# Roll_No    1
# Name       0
# Math       1
# English    1
# Class      0
# dtype: int64

# %% [markdown]
# drop raws that all values are missed

# %%
data.dropna(how="all",inplace=True)

# %% [markdown]
# Remove Duplicates

# %%
data.drop_duplicates(inplace=True)
data
# Out:
#    Roll_No   Name  Math  English Class
# 0    101.0   Ali   88.0     80.0    6A
# 1    102.0   sara   NaN     70.0    6A
# 2    103.0  AHMED  75.0      NaN    6B
# 3    104.0   hina  90.0     85.0    6B
# 5      NaN  Usman  80.0     88.0    6C

# %% [markdown]
# fill values

# %%
data["Roll_No"].fillna(0,inplace=True)
data.tail()
# Out:
# /tmp/ipython-input-484654113.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   data["Roll_No"].fillna(0,inplace=True)
#    Roll_No   Name  Math  English Class
# 0    101.0   Ali   88.0     80.0    6A
# 1    102.0   sara   NaN     70.0    6A
# 2    103.0  AHMED  75.0      NaN    6B
# 3    104.0   hina  90.0     85.0    6B
# 5      0.0  Usman  80.0     88.0    6C

# %%
data.fillna(data.mean(numeric_only=True),inplace=True)
print(data)
# Out:
#    Roll_No   Name   Math  English Class
# 0    101.0   Ali   88.00    80.00    6A
# 1    102.0   sara  83.25    70.00    6A
# 2    103.0  AHMED  75.00    80.75    6B
# 3    104.0   hina  90.00    85.00    6B
# 5      0.0  Usman  80.00    88.00    6C

# %% [markdown]
# Fix Data Types

# %%
data["Roll_No"]=data["Roll_No"].astype(int)

# %% [markdown]
# Clean Text Columns

# %%
data["Name"]=data["Name"].str.title()# capitalize nicely.
data
# Out:
#    Roll_No   Name   Math  English Class
# 0      101   Ali   88.00    80.00    6A
# 1      102   Sara  83.25    70.00    6A
# 2      103  Ahmed  75.00    80.75    6B
# 3      104   Hina  90.00    85.00    6B
# 5        0  Usman  80.00    88.00    6C

# %% [markdown]
# data is cleaned

# %% [markdown]
# Add Total (Math + English).

# %%
data["Total_Marks"]=data["Math"]+data["English"]

# %% [markdown]
# Assign Grade (A, B, C, Fail).

# %%
def assign_grade(e):
  if e>180:
    return "A"
  elif e>170:
    return "B"
  elif e>160:
    return "C"
  else:
    return "F"
# grade assigning to total_marks
data["Grade"]=data["Total_Marks"].apply(assign_grade)

# %% [markdown]
# Rename Columns

# %%
data.rename(columns={"Math":"Math_Marks","English":"English_Marks"},inplace=True)
data
# Out:
#    Roll_No   Name  Math_Marks  English_Marks Class  Total_Marks Grade
# 0      101   Ali        88.00          80.00    6A       168.00     C
# 1      102   Sara       83.25          70.00    6A       153.25     F
# 2      103  Ahmed       75.00          80.75    6B       155.75     F
# 3      104   Hina       90.00          85.00    6B       175.00     B
# 5        0  Usman       80.00          88.00    6C       168.00     C

# %% [markdown]
# Sort students to find Toppers.

# %%
data.sort_values(by="Total_Marks", ascending=False,inplace=True)
data
# Out:
#    Roll_No   Name  Math_Marks  English_Marks Class  Total_Marks Grade
# 3      104   Hina       90.00          85.00    6B       175.00     B
# 0      101   Ali        88.00          80.00    6A       168.00     C
# 5        0  Usman       80.00          88.00    6C       168.00     C
# 2      103  Ahmed       75.00          80.75    6B       155.75     F
# 1      102   Sara       83.25          70.00    6A       153.25     F

# %% [markdown]
# Export final Report

# %%
data.to_csv("final_school_data.csv",index=False)

# %% [markdown]
# # Time Series Analysis – "Working with Dates"
#
# **goal:** Learn to handle,manipulate and analyze data that is recorded over time
#
# so far, we treated date as string (e.g "2025-11-10").
# We needs to tell pandas that these are actual dates

# %% [markdown]
# **Converting to Datetime:**
#
# The most crucial first step is converting date columns from plain text (string or object) into a special Pandas **datetime** type.
#
# > pd.to_datetime()

# %%
# Sample sales data with dates as strings
sales_data = pd.DataFrame({
    'sale_date': ['2025-11-01', '2025-11-02', '2025-11-03', '2025-11-04', '2025-11-05'],
    'items_sold': [25, 30, 22, 28, 35]
})
print(f"sales_data:{sales_data}\n Data_Type:\n {sales_data.dtypes}")
# Out:
# sales_data:    sale_date  items_sold
# 0  2025-11-01          25
# 1  2025-11-02          30
# 2  2025-11-03          22
# 3  2025-11-04          28
# 4  2025-11-05          35
#  Data_Type:
#  sale_date     object
# items_sold     int64
# dtype: object
